# %%
import wfdb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent

sys.path.insert(
    0,
    str(PROJECT_ROOT),
)

# %%
record_path = Path("../data/raw/ltafdb/00")

record = wfdb.rdrecord(str(record_path))
ann = wfdb.rdann(str(record_path), "atr")

signal = record.p_signal

signal.shape
# Out:
# (9661440, 2)

# %%
fs = record.fs

seconds = 60

n = int(fs * seconds)

t = np.arange(n) / fs

plt.figure(figsize=(14,4))

plt.plot(
    t,
    signal[:n,0],
)

plt.xlabel("Time (s)")
plt.ylabel("mV")
plt.title("ECG Lead 1")

plt.show()

# %%
for rec in ["00", "01", "03"]:

    ann = wfdb.rdann(
        f"../data/raw/ltafdb/{rec}",
        "atr",
    )

    rhythms = []

    for note in ann.aux_note:

        note = note.strip()

        if note:
            rhythms.append(note)

    print(rec)
    print(set(rhythms))
    print()
# Out:
# 00
# {'(N', '(VT', '\x01 Aux', '(AFIB'}
#
# 01
# {'(N', '\x01 Aux', 'MISSB', '(SBR', '(T', '(AFIB', 'PSE', '(SVTA', '(AB', '(B'}
#
# 03
# {'(N', '(VT', '\x01 Aux', 'MISSB', '(SBR', '(T', '(AFIB', '(SVTA', '(AB', '(B'}

# %%
from scripts.preprocess import build_label_array

labels = build_label_array(
    signal.shape[0],
    ann,
)

# %%
seconds = 30000

n = seconds * fs

t = np.arange(n) / fs

fig, ax = plt.subplots(
    2,
    1,
    figsize=(15,6),
    sharex=True,
)

ax[0].plot(
    t,
    signal[:n,0],
)

ax[0].set_title("ECG")

ax[1].plot(
    t,
    labels[:n],
)

ax[1].set_title("AF Label")

plt.show()

# %%
data_dir = Path("../data/processed")

files = sorted(data_dir.glob("*.npz"))

len(files)
# Out:
# 6

# %%
file = files[0]

print(file)
# Out:
# ../data/processed/00.npz

# %%
data = np.load(file)

list(data.keys())
data['y'][:10]
data['X'][0]
# Out:
# array([[-0.00644999,  0.01069999],
#        [ 0.00644999,  0.        ],
#        [-0.00644999,  0.01069999],
#        ...,
#        [ 0.08384987,  0.00535   ],
#        [ 0.09029986,  0.00535   ],
#        [ 0.11609982,  0.        ]], dtype=float32)

# %%
X = data["X"]
y = data["y"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (7547, 1280, 2)
# y shape: (7547,)

# %%
idx = 0

plt.figure(figsize=(12,4))

plt.plot(
    X[idx,:,0]
)

plt.title(
    f"Window {idx} Label={y[idx]}"
)

plt.show()

# %%
idx = 0

fig, ax = plt.subplots(
    2,
    1,
    figsize=(12,6),
    sharex=True,
)

ax[0].plot(X[idx,:,0])
ax[0].set_title("Lead 1")

ax[1].plot(X[idx,:,1])
ax[1].set_title("Lead 2")

plt.show()

# %%
all_labels = []

for file in files:

    data = np.load(file)

    all_labels.append(
        data["y"]
    )

all_labels = np.concatenate(
    all_labels
)

len(all_labels)
# Out:
# 50718

# %%
pd.Series(
    all_labels
).value_counts()
# Out:
# 0    45982
# 1     4736
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))

plt.hist(
    all_labels,
    bins=2,
)

plt.xticks([0,1])

plt.xlabel("Label")
plt.ylabel("Count")

plt.title(
    "AF vs Non-AF"
)

plt.show()

# %%
af_window = None

for file in files:

    data = np.load(file)

    X = data["X"]
    y = data["y"]

    matches = np.where(y == 1)[0]

    if len(matches):

        af_window = X[matches[0]]
        break

# %%
normal_window = None

for file in files:

    data = np.load(file)

    X = data["X"]
    y = data["y"]

    matches = np.where(y == 0)[0]

    if len(matches):

        normal_window = X[matches[0]]
        break

# %%
fig, ax = plt.subplots(
    2,
    1,
    figsize=(14,6),
)

ax[0].plot(
    normal_window[:,0]
)

ax[0].set_title(
    "Normal Rhythm"
)

ax[1].plot(
    af_window[:,0]
)

ax[1].set_title(
    "Atrial Fibrillation"
)

plt.tight_layout()

plt.show()

# %%
n_files = len(files)

n_windows = 0

for file in files:

    data = np.load(file)

    n_windows += len(
        data["y"]
    )

print(
    f"Files: {n_files}"
)

print(
    f"Windows: {n_windows}"
)

print(
    f"AF fraction: "
    f"{all_labels.mean():.3f}"
)
# Out:
# Files: 6
# Windows: 50718
# AF fraction: 0.093

# %%
for file in files:

    data = np.load(file)

    print(
        file.name,
        data["X"].shape,
        data["y"].shape,
    )
# Out:
# 00.npz (7547, 1280, 2) (7547,)
# 01.npz (7403, 1280, 2) (7403,)
# 03.npz (8735, 1280, 2) (8735,)
# 05.npz (8753, 1280, 2) (8753,)
# 06.npz (9089, 1280, 2) (9089,)
# 07.npz (9191, 1280, 2) (9191,)

# %%
from collections import Counter

record = wfdb.rdrecord("../data/raw/ltafdb/00")
ann = wfdb.rdann("../data/raw/ltafdb/00", "atr")

Counter(
    note.strip()
    for note in ann.aux_note
)
# Out:
# Counter({'': 106247, '(AFIB': 44, '(VT': 40, '(N': 5, '\x01 Aux': 1})
